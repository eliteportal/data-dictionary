# %%
import os
import pandas as pd
import numpy as np
import re
import datetime
import pathlib

# custom package(s)
from utils import utils, synapse_login

# %%
syn = synapse_login.main()
# Out:
# Welcome, Nicholas Lee!

# %%
dm_name = "../EL.data.model.csv"
output_path = os.path.join("../backups", dm_name)

dm_path = pathlib.Path(dm_name).resolve()
output_path = pathlib.Path(output_path).resolve()

# %%
dm = utils.load_and_backup_dm(dm_path, output_path)

# %%
# for any attributes that do not currently have a module name. In an attempt to remove the bracket tab in the webpage
dm.loc[dm["Module"].isna(), "Module"] = "Unspecified"

# %%
np.sort(dm["Module"].dropna().unique())
# Out:
# array(['Assay', 'Assay Metadata', 'BaseAnnotation', 'Instrument',
#        'Metadata', 'Model Organism', 'Omics', 'Ontology', 'Other',
#        'Project', 'Sample Metadata', 'Template', 'Unit', 'Unspecified',
#        'Valid Value'], dtype=object)

# %%
dm.loc[dm["Module"] == "Boolean", "Module"] = "Valid Value"

# %%
dm.loc[dm["Module"].isin(["Project", "Instrument", "Assay Metadata"])].sort_values(
    by="Module"
)
# Out:
#      Unnamed: 0.1  Unnamed: 0
# 52             52          52  \
# 53             53          53
# 54             54          54
# 55             55          55
# 56             56          56
# 57             57          57
# 58             58          58
# 342           342         342
# 343           343         343
# 344           344         344
# 345           345         345
# 346           346         346
# 347           347         347
# 351           351         351
# 349           349         349
# 350           350         350
# 341           341         341
# 352           352         352
# 353           353         353
# 354           354         354
# 348           348         348
# 340           340         340
# 337           337         337
# 338           338         338
# 236           236         236
# 298           298         298
# 303           303         303
# 304           304         304
# 339           339         339
# 331           331         331
# 330           330         330
# 333           333         333
# 334           334         334
# 335           335         335
# 336           336         336
# 332           332         332
# 325           325         325
# 368           368         368
# 364           364         364
# 370           370         370
#
#                                              Attribute
# 52                                        reagentID(s)  \
# 53                                         reagentName
# 54                                 reagentManufacturer
# 55                                reagentCatalogNumber
# 56                                    reagentLotNumber
# 57                                      reagentWeblink
# 58                                      reagentContact
# 342         Illumina HumanOmniExpress-24 v1.2 BeadChip
# 343  Illumina Infinium MethylationEPIC BeadChip v1....
# 344  Illumina Infinium MethylationEPIC BeadChip v2....
# 345        Illumina MouseWG-6 v2.0 expression BeadChip
# 346                              Illumina NextSeq 1000
# 347                              Illumina NextSeq 2000
# 351                                 Illumina Omni2pt5M
# 349                               Illumina NextSeq 550
# 350                              Illumina NovaSeq 6000
# 341         Illumina HumanOmniExpress-24 v1.0 BeadChip
# 352                                    Illumina Omni5M
# 353                          Illumina WholeGenome DASL
# 354                                      Illumina h650
# 348                               Illumina NextSeq 500
# 340                       Illumina HumanOmni1-Quadv1.0
# 337              Illumina Human660W-Quad v1.0 BeadChip
# 338                               Illumina HumanHap300
# 236                 10x Visium Spatial Gene Expression
# 298                    EnVision 2103 Multiplate Reader
# 303  Exploris 240Exploris 480quadrupole time-of-flight
# 304                                           FIA-MSMS
# 339                       Illumina HumanMethylation450
# 331                       Illumina Genome Analyzer IIx
# 330                                        Illumina 1M
# 333                                Illumina HiSeq 2500
# 334                                Illumina HiSeq 3000
# 335                                Illumina HiSeq 4000
# 336                                   Illumina HiSeq X
# 332                                Illumina HiSeq 2000
# 325                                                ILO
# 368                                                 LG
# 364                                                 LC
# 370                                               LLFS
#
#                                            Description Valid Values DependsOn
# 52   One or more identifiers, separated by a semico...          NaN       NaN  \
# 53   The reagent name is an alternative to the Reag...          NaN       NaN
# 54   The manufacturer is the source of a reagent an...          NaN       NaN
# 55   If the assay reagent is a commercial product, ...          NaN       NaN
# 56   The lot number is often provided by a reagent ...          NaN       NaN
# 57   An internet address that may provide details o...          NaN       NaN
# 58   The contact information is particularly helpfu...          NaN       NaN
# 342                              Instrument Model Name          NaN       NaN
# 343                              Instrument Model Name          NaN       NaN
# 344                              Instrument Model Name          NaN       NaN
# 345                              Instrument Model Name          NaN       NaN
# 346                              Instrument Model Name          NaN       NaN
# 347                              Instrument Model Name          NaN       NaN
# 351                              Instrument Model Name          NaN       NaN
# 349                              Instrument Model Name          NaN       NaN
# 350                              Instrument Model Name          NaN       NaN
# 341                              Instrument Model Name          NaN       NaN
# 352                              Instrument Model Name          NaN       NaN
# 353                              Instrument Model Name          NaN       NaN
# 354                              Instrument Model Name          NaN       NaN
# 348                              Instrument Model Name          NaN       NaN
# 340                              Instrument Model Name          NaN       NaN
# 337                              Instrument Model Name          NaN       NaN
# 338                              Instrument Model Name          NaN       NaN
# 236                              Instrument Model Name          NaN       NaN
# 298                              Instrument Model Name          NaN       NaN
# 303                              Instrument Model Name          NaN       NaN
# 304                              Instrument Model Name          NaN       NaN
# 339                              Instrument Model Name          NaN       NaN
# 331                              Instrument Model Name          NaN       NaN
# 330                              Instrument Model Name          NaN       NaN
# 333                              Instrument Model Name          NaN       NaN
# 334                              Instrument Model Name          NaN       NaN
# 335                              Instrument Model Name          NaN       NaN
# 336                              Instrument Model Name          NaN       NaN
# 332                              Instrument Model Name          NaN       NaN
# 325                                       Project name          NaN       NaN
# 368                                       Project name          NaN       NaN
# 364                                       Project name          NaN       NaN
# 370                                       Project name          NaN       NaN
#
#      Properties Required        Parent  DependsOn Component
# 52          NaN    False  DataProperty                  NaN  \
# 53          NaN    False  DataProperty                  NaN
# 54          NaN    False  DataProperty                  NaN
# 55          NaN    False  DataProperty                  NaN
# 56          NaN    False  DataProperty                  NaN
# 57          NaN    False  DataProperty                  NaN
# 58          NaN    False  DataProperty                  NaN
# 342         NaN    False    ValidValue                  NaN
# 343         NaN    False    ValidValue                  NaN
# 344         NaN    False    ValidValue                  NaN
# 345         NaN    False    ValidValue                  NaN
# 346         NaN    False    ValidValue                  NaN
# 347         NaN    False    ValidValue                  NaN
# 351         NaN    False    ValidValue                  NaN
# 349         NaN    False    ValidValue                  NaN
# 350         NaN    False    ValidValue                  NaN
# 341         NaN    False    ValidValue                  NaN
# 352         NaN    False    ValidValue                  NaN
# 353         NaN    False    ValidValue                  NaN
# 354         NaN    False    ValidValue                  NaN
# 348         NaN    False    ValidValue                  NaN
# 340         NaN    False    ValidValue                  NaN
# 337         NaN    False    ValidValue                  NaN
# 338         NaN    False    ValidValue                  NaN
# 236         NaN    False    ValidValue                  NaN
# 298         NaN    False    ValidValue                  NaN
# 303         NaN    False    ValidValue                  NaN
# 304         NaN    False    ValidValue                  NaN
# 339         NaN    False    ValidValue                  NaN
# 331         NaN    False    ValidValue                  NaN
# 330         NaN    False    ValidValue                  NaN
# 333         NaN    False    ValidValue                  NaN
# 334         NaN    False    ValidValue                  NaN
# 335         NaN    False    ValidValue                  NaN
# 336         NaN    False    ValidValue                  NaN
# 332         NaN    False    ValidValue                  NaN
# 325         NaN    False    ValidValue                  NaN
# 368         NaN    False    ValidValue                  NaN
# 364         NaN    False    ValidValue                  NaN
# 370         NaN    False    ValidValue                  NaN
#
#                        Source Validation Rules          Module Type  Ontology
# 52   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 53   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 54   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 55   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 56   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 57   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 58   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 342                       NaN              NaN      Instrument  NaN       NaN
# 343                       NaN              NaN      Instrument  NaN       NaN
# 344                       NaN              NaN      Instrument  NaN       NaN
# 345                       NaN              NaN      Instrument  NaN       NaN
# 346                       NaN              NaN      Instrument  NaN       NaN
# 347                       NaN              NaN      Instrument  NaN       NaN
# 351                       NaN              NaN      Instrument  NaN       NaN
# 349                       NaN              NaN      Instrument  NaN       NaN
# 350                       NaN              NaN      Instrument  NaN       NaN
# 341                       NaN              NaN      Instrument  NaN       NaN
# 352                       NaN              NaN      Instrument  NaN       NaN
# 353                       NaN              NaN      Instrument  NaN       NaN
# 354                       NaN              NaN      Instrument  NaN       NaN
# 348                       NaN              NaN      Instrument  NaN       NaN
# 340                       NaN              NaN      Instrument  NaN       NaN
# 337                       NaN              NaN      Instrument  NaN       NaN
# 338                       NaN              NaN      Instrument  NaN       NaN
# 236                       NaN              NaN      Instrument  NaN       NaN
# 298                       NaN              NaN      Instrument  NaN       NaN
# 303                       NaN              NaN      Instrument  NaN       NaN
# 304                       NaN              NaN      Instrument  NaN       NaN
# 339                       NaN              NaN      Instrument  NaN       NaN
# 331                       NaN              NaN      Instrument  NaN       NaN
# 330                       NaN              NaN      Instrument  NaN       NaN
# 333                       NaN              NaN      Instrument  NaN       NaN
# 334                       NaN              NaN      Instrument  NaN       NaN
# 335                       NaN              NaN      Instrument  NaN       NaN
# 336                       NaN              NaN      Instrument  NaN       NaN
# 332                       NaN              NaN      Instrument  NaN       NaN
# 325                       NaN              NaN         Project  NaN       NaN
# 368                       NaN              NaN         Project  NaN       NaN
# 364                       NaN              NaN         Project  NaN       NaN
# 370                       NaN              NaN         Project  NaN       NaN

# %%
# Update descriptions
dm.loc[dm["Module"].isin(["Instrument"]),
       "Description"] = "Instrument Model Name"
dm.loc[dm["Module"].isin(["Study"]), "Description"] = "Project name"

# %%
dm.loc[dm["Module"].isin(["Study"]), "Module"] = "Project"

# %%
dm.loc[~dm["DependsOn"].isna(),]
# Out:
#      Unnamed: 0.1  Unnamed: 0
# 178           178         178  \
# 179           179         179
# 180           180         180
# 181           181         181
# 182           182         182
# 183           183         183
# 184           184         184
# 185           185         185
# 186           186         186
# 187           187         187
# 188           188         188
# 189           189         189
# 190           190         190
# 191           191         191
# 192           192         192
# 193           193         193
# 194           194         194
# 195           195         195
# 196           196         196
# 197           197         197
# 198           198         198
# 199           199         199
# 200           200         200
# 201           201         201
# 202           202         202
# 203           203         203
# 204           204         204
# 205           205         205
# 206           206         206
# 207           207         207
# 208           208         208
# 209           209         209
# 210           210         210
# 211           211         211
# 212           212         212
# 213           213         213
# 214           214         214
# 215           215         215
# 216           216         216
# 217           217         217
# 218           218         218
# 219           219         219
# 612           612         612
# 613           613         613
# 614           614         614
# 615           615         615
# 616           616         616
# 617           617         617
# 618           618         618
# 619           619         619
# 620           620         620
# 621           621         621
# 622           622         622
# 623           623         623
#
#                                             Attribute
# 178                                   OtherSampleType  \
# 179                    OtherTechnologyPlatformVersion
# 180                             OtherPlatformLocation
# 181                             OtherDnaBatchSizeUnit
# 182                                  OtherLibraryPrep
# 183                     OtherLibraryPreparationMethod
# 184                               OtherLibraryVersion
# 185                      OtherSequencingBatchSizeUnit
# 186                              OtherReadLengthUnits
# 187                               OtherRepositoryName
# 188                               OtherTranscriptType
# 189                             OtherRnaBatchSizeUnit
# 190                                     YesUseReagent
# 191                                   YesUseTreatment
# 192       OtherMetabolomics HumanmeasurementTechnique
# 193                            OtherMsAnalyzerTypeMS1
# 194                            OtherMsAnalyzerTypeMS2
# 195                             OtherMsAssayTechnique
# 196                                  TargetedMsTarget
# 197                                OtherMsAnalyteType
# 198                            OtherMsInstrumentModel
# 199                            OtherSampleIntdocution
# 200                                 OtherDatabaseName
# 201                               OtherDatabaseSource
# 202                            YesHasIonizationSource
# 203                          OtherVaccumPressureUnits
# 204                             OtherLensVoltageUnits
# 205                                YesHasAssayControl
# 206                                  OtherControlType
# 207                    OtherExperimentalBatchSizeUnit
# 208                                OtherBatchSizeUnit
# 209                          OtherSampleBatchSizeUnit
# 210                     OtherAcquisitionBatchSizeUnit
# 211                      OtherProcessingBatchSizeUnit
# 212                             OtherExtractionMethod
# 213                          OtherProteomicsAssayType
# 214                              OtherDigestionMethod
# 215                       OtherModificationParameters
# 216                               OtherCleavageAgents
# 217                                Hispanic or latino
# 218                                              TRUE
# 219                            CaptiveCaptivityStatus
# 612                                 Biospecimen human
# 613                              Biospecimen nonHuman
# 614                                  Individual Human
# 615                               Individual nonHuman
# 616                                Metabolomics Human
# 617                                        Microbiome
# 618                                            RNAseq
# 619                           Whole Genome Sequencing
# 620  bsSeq (bisulfite-seq WGBS methylseq methylomics)
# 621                                        genotyping
# 622                                        proteomics
# 623                                          scRNAseq
#
#                                            Description
# 178     If "other" is selected list the type of sample  \
# 179   If "other" list the name of the platform version
# 180  If "other" list the name of the platform location
# 181                    If "other" list unit of measure
# 182  If "other" list the name of the general strate...
# 183  If "other" list the name of the library prepar...
# 184    If "other" list the name of the library version
# 185                    If "other" list unit of measure
# 186             If "other" provide the unit of measure
# 187         If "other" list the name of the repository
# 188                If "other" list the transcript type
# 189                    If "other" list unit of measure
# 190  One or more identifiers, separated by a semico...
# 191  One or more identifiers, separated by a semico...
# 192  If "other" is selected list the name of the me...
# 193  If "other" is selected list the name of the ma...
# 194  If "other" is selected list the name of the ma...
# 195  If "other" is selected list the name of the ma...
# 196      the type of biospecimen subjected to analysis
# 197               If "other" list the type of analyte
# 198  If "other" is selected list the name of the in...
# 199  If "other" list the name of the sample introdu...
# 200    If "other" list the name of the search database
# 201    If "other" list the name of the database source
# 202  Ion charge state (positive or negative-ion ana...
# 203             If "other" provide the unit of measure
# 204             If "other" provide the unit of measure
# 205  Control samples suitable for normalization and...
# 206                If "other" specify the control type
# 207                   If "other" list units of measure
# 208                If "other" list the unit of measure
# 209                If "other" list the unit of measure
# 210                   If "other" list units of measure
# 211                   If "other" list units of measure
# 212  If "other" list the name of the extraction method
# 213  If "other" is selected list the name of the ty...
# 214              If "other" list the type of digestion
# 215  If "other" is selected, list the custom modifi...
# 216     If "other" is selected, list the enzyme name.
# 217  A coded value specifying the self-declared eth...
# 218                 Indicate the disease or condition.
# 219  The duration of captivity in months for the in...
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
# 617                                                NaN
# 618                                                NaN
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                                           Valid Values
# 178                                                NaN  \
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196  Protein,metabolite,Lipid,Other,Unknown,Not col...
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201                                                NaN
# 202                                  Positive,Negative
# 203                                                NaN
# 204                                                NaN
# 205  GIS,GoldenWest,NIST SRM 1950,AIBL pool,Baker p...
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219               Unknown,Not collected,Not applicable
# 612                                                NaN
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
# 617                                                NaN
# 618                                                NaN
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                                              DependsOn  Properties Required
# 178                                  specifySampleType         NaN    False  \
# 179                             specifyPlatformVersion         NaN    False
# 180                            specifyPlatformLocation         NaN    False
# 181                            specifyDNABatchSizeUnit         NaN    False
# 182                                 specifyLibraryPrep         NaN    False
# 183                    specifyLibraryPreparationMethod         NaN    False
# 184                              specifyLibraryVersion         NaN    False
# 185                     specifySequencingBatchSizeUnit         NaN    False
# 186                             specifyReadLengthUnits         NaN    False
# 187                              specifyRepositoryName         NaN    False
# 188                              specifyTranscriptType         NaN    False
# 189                            specifyRNABatchSizeUnit         NaN    False
# 190                                       reagentID(s)         NaN    False
# 191                                     treatmentID(s)         NaN    False
# 192                        specifyMeasurementTechnique         NaN    False
# 193                           specifyMSAnalyzerTypeMS1         NaN    False
# 194                           specifyMSAnalyzerTypeMS2         NaN    False
# 195                            specifyMSAssayTechnique         NaN    False
# 196                                      msAnalyteType         NaN    False
# 197                               specifyMSAnalyteType         NaN    False
# 198                           specifyMSInstrumentModel         NaN    False
# 199                          specifySampleIntroduction         NaN    False
# 200                                specifyDatabaseName         NaN    False
# 201                              specifyDatabaseSource         NaN    False
# 202                                        ionProperty         NaN    False
# 203                          specifyVacuumPressueUnits         NaN    False
# 204                            specifyLensVoltageUnits         NaN    False
# 205                                        controlType         NaN    False
# 206                                 specifyControlType         NaN    False
# 207                  specifyExperimentalBatchSizeUnits         NaN    False
# 208                              specifyBatchSizeUnits         NaN    False
# 209                        specifySampleBatchSizeUnits         NaN    False
# 210                   specifyAcquisitionBatchSizeUnits         NaN    False
# 211                     specifyProcessingBatchSizeUnit         NaN    False
# 212                            specifyExtractionMethod         NaN    False
# 213                         specifyProteomicsAssayType         NaN    False
# 214                             specifyDigestionMethod         NaN    False
# 215                 specifyOtherModificationParameters         NaN    False
# 216                          specifyOtherCleavageAgent         NaN    False
# 217                                    ethnicGroupCode         NaN    False
# 218                                          diagnosis         NaN    False
# 219                                  captivityDuration         NaN    False
# 612  individualID,specimenID,specimenType,specimenA...         NaN     True
# 613  individualID,specimenID,specimenIdSource,dataG...         NaN     True
# 614  individualID,cohort,studyCode,fieldCenterCode,...         NaN     True
# 615  individualID,cohort,studyCode,taxon,speciesGro...         NaN     True
# 616  specimenID,sampleType,specifySampleType,specif...         NaN     True
# 617  specimenID,sampleType,specifySampleType,specif...         NaN     True
# 618  specimenID,sampleType,specifySampleType,specif...         NaN     True
# 619  specimenID,sampleType,specifySampleType,specif...         NaN     True
# 620  specimenID,sampleType,specifySampleType,specif...         NaN     True
# 621  specimenID,sampleType,specifySampleType,useRea...         NaN     True
# 622  specimenID,sampleType,specifySampleType,specif...         NaN     True
# 623  specimenID,sampleType,specifySampleType,specif...         NaN     True
#
#          Parent  DependsOn Component
# 178  ValidValue                  NaN  \
# 179  ValidValue                  NaN
# 180  ValidValue                  NaN
# 181  ValidValue                  NaN
# 182  ValidValue                  NaN
# 183  ValidValue                  NaN
# 184  ValidValue                  NaN
# 185  ValidValue                  NaN
# 186  ValidValue                  NaN
# 187  ValidValue                  NaN
# 188  ValidValue                  NaN
# 189  ValidValue                  NaN
# 190  ValidValue                  NaN
# 191  ValidValue                  NaN
# 192  ValidValue                  NaN
# 193  ValidValue                  NaN
# 194  ValidValue                  NaN
# 195  ValidValue                  NaN
# 196  ValidValue                  NaN
# 197  ValidValue                  NaN
# 198  ValidValue                  NaN
# 199  ValidValue                  NaN
# 200  ValidValue                  NaN
# 201  ValidValue                  NaN
# 202  ValidValue                  NaN
# 203  ValidValue                  NaN
# 204  ValidValue                  NaN
# 205  ValidValue                  NaN
# 206  ValidValue                  NaN
# 207  ValidValue                  NaN
# 208  ValidValue                  NaN
# 209  ValidValue                  NaN
# 210  ValidValue                  NaN
# 211  ValidValue                  NaN
# 212  ValidValue                  NaN
# 213  ValidValue                  NaN
# 214  ValidValue                  NaN
# 215  ValidValue                  NaN
# 216  ValidValue                  NaN
# 217  ValidValue                  NaN
# 218  ValidValue                  NaN
# 219  ValidValue                  NaN
# 612    Template                  NaN
# 613    Template                  NaN
# 614    Template                  NaN
# 615    Template                  NaN
# 616    Template                  NaN
# 617    Template                  NaN
# 618    Template                  NaN
# 619    Template                  NaN
# 620    Template                  NaN
# 621    Template                  NaN
# 622    Template                  NaN
# 623    Template                  NaN
#
#                                                 Source Validation Rules
# 178                                   Sage Bionetworks              NaN  \
# 179                                   Sage Bionetworks              NaN
# 180                                   Sage Bionetworks              NaN
# 181                                   Sage Bionetworks              NaN
# 182                                   Sage Bionetworks              NaN
# 183                                   Sage Bionetworks              NaN
# 184                                   Sage Bionetworks              NaN
# 185                                   Sage Bionetworks              NaN
# 186                                   Sage Bionetworks              NaN
# 187                                   Sage Bionetworks              NaN
# 188                                   Sage Bionetworks              NaN
# 189                                   Sage Bionetworks              NaN
# 190                           Sage Bionetworks,ImmPort              NaN
# 191                           Sage Bionetworks,ImmPort              NaN
# 192                                   Sage Bionetworks              NaN
# 193                                   Sage Bionetworks              NaN
# 194                                   Sage Bionetworks              NaN
# 195                                   Sage Bionetworks              NaN
# 196        http://purl.obolibrary.org/obo/NCIT_C156434              NaN
# 197                                   Sage Bionetworks              NaN
# 198                                   Sage Bionetworks              NaN
# 199                                   Sage Bionetworks              NaN
# 200                                   Sage Bionetworks              NaN
# 201                                   Sage Bionetworks              NaN
# 202  Sage Bionetworks,Proposed minimum metadata rel...              NaN
# 203                                   Sage Bionetworks              NaN
# 204                                   Sage Bionetworks              NaN
# 205  https://doi.org/10.1101/2020.05.19.105197https...              NaN
# 206                                   Sage Bionetworks              NaN
# 207                                                NaN              NaN
# 208                                   Sage Bionetworks              NaN
# 209                                   Sage Bionetworks              NaN
# 210                                                NaN              NaN
# 211                                   Sage Bionetworks              NaN
# 212                                   Sage Bionetworks              NaN
# 213                                   Sage Bionetworks              NaN
# 214                                   Sage Bionetworks              NaN
# 215                                   Sage Bionetworks              NaN
# 216                                   Sage Bionetworks              NaN
# 217  https://ncithesaurus.nci.nih.gov/ncitbrowser/p...              NaN
# 218  LLFS data dictionary,LLFS data dictionary,LLFS...              NaN
# 219  https://www.animalaudiograms.org/audiogram_met...              NaN
# 612                                                NaN              NaN
# 613                                                NaN              NaN
# 614                                                NaN              NaN
# 615                                                NaN              NaN
# 616                                                NaN              NaN
# 617                                                NaN              NaN
# 618                                                NaN              NaN
# 619                                                NaN              NaN
# 620                                                NaN              NaN
# 621                                                NaN              NaN
# 622                                                NaN              NaN
# 623                                                NaN              NaN
#
#           Module Type  Ontology
# 178        Other  NaN       NaN
# 179        Other  NaN       NaN
# 180        Other  NaN       NaN
# 181        Other  NaN       NaN
# 182        Other  NaN       NaN
# 183        Other  NaN       NaN
# 184        Other  NaN       NaN
# 185        Other  NaN       NaN
# 186        Other  NaN       NaN
# 187        Other  NaN       NaN
# 188        Other  NaN       NaN
# 189        Other  NaN       NaN
# 190  Unspecified  NaN       NaN
# 191  Unspecified  NaN       NaN
# 192        Other  NaN       NaN
# 193        Other  NaN       NaN
# 194        Other  NaN       NaN
# 195        Other  NaN       NaN
# 196  Unspecified  NaN       NaN
# 197        Other  NaN       NaN
# 198        Other  NaN       NaN
# 199        Other  NaN       NaN
# 200        Other  NaN       NaN
# 201        Other  NaN       NaN
# 202  Unspecified  NaN       NaN
# 203        Other  NaN       NaN
# 204        Other  NaN       NaN
# 205  Unspecified  NaN       NaN
# 206        Other  NaN       NaN
# 207        Other  NaN       NaN
# 208        Other  NaN       NaN
# 209        Other  NaN       NaN
# 210        Other  NaN       NaN
# 211        Other  NaN       NaN
# 212        Other  NaN       NaN
# 213        Other  NaN       NaN
# 214        Other  NaN       NaN
# 215        Other  NaN       NaN
# 216        Other  NaN       NaN
# 217  Unspecified  NaN       NaN
# 218  Unspecified  NaN       NaN
# 219  Unspecified  NaN       NaN
# 612     Template  NaN       NaN
# 613     Template  NaN       NaN
# 614     Template  NaN       NaN
# 615     Template  NaN       NaN
# 616     Template  NaN       NaN
# 617     Template  NaN       NaN
# 618     Template  NaN       NaN
# 619     Template  NaN       NaN
# 620     Template  NaN       NaN
# 621     Template  NaN       NaN
# 622     Template  NaN       NaN
# 623     Template  NaN       NaN

# %%
# Pull grant information

# %%
# Fix Other values
dm.loc[
    dm["Attribute"].str.contains("^other|^specify", regex=True, flags=re.IGNORECASE),
    "Module",
] = "Other"

# %%
# Fix "specify" values
dm.loc[
    dm["Attribute"].str.contains("^specify", regex=True, flags=re.IGNORECASE), "Parent"
] = "specification"

# %%
dm.loc[
    dm["Attribute"].str.contains("^other|^specify", regex=True, flags=re.IGNORECASE),
]
# Out:
#      Unnamed: 0.1  Unnamed: 0                        Attribute
# 2               2           2                specifySampleType  \
# 3               3           3      specifyMeasurementTechnique
# 5               5           5           specifyPlatformVersion
# 7               7           7          specifyPlatformLocation
# 12             12          12          specifyDNABatchSizeUnit
# ..            ...         ...                              ...
# 438           438         438        OtherConversionRatioUnits
# 439           439         439  OtherExperiementalBatchSizeUnit
# 440           440         440            OtherLensVoltagesUnit
# 441           441         441          OtherVacuumPressureUnit
# 442           442         442      OtherYesHasIonizationSource
#
#                                      Description Valid Values DependsOn
# 2    Value is determined by the data contributor          NaN       NaN  \
# 3    Value is determined by the data contributor          NaN       NaN
# 5    Value is determined by the data contributor          NaN       NaN
# 7    Value is determined by the data contributor          NaN       NaN
# 12   Value is determined by the data contributor          NaN       NaN
# ..                                           ...          ...       ...
# 438                                          NaN          NaN       NaN
# 439                                          NaN          NaN       NaN
# 440                                          NaN          NaN       NaN
# 441                                          NaN          NaN       NaN
# 442                                          NaN          NaN       NaN
#
#      Properties Required         Parent  DependsOn Component
# 2           NaN    False  specification                  NaN  \
# 3           NaN    False  specification                  NaN
# 5           NaN    False  specification                  NaN
# 7           NaN    False  specification                  NaN
# 12          NaN    False  specification                  NaN
# ..          ...      ...            ...                  ...
# 438         NaN    False     ValidValue                  NaN
# 439         NaN    False     ValidValue                  NaN
# 440         NaN    False     ValidValue                  NaN
# 441         NaN    False     ValidValue                  NaN
# 442         NaN    False     ValidValue                  NaN
#
#                Source Validation Rules Module    Type  Ontology
# 2    Sage Bionetworks              NaN  Other  String       NaN
# 3    Sage Bionetworks              NaN  Other  String       NaN
# 5    Sage Bionetworks              NaN  Other  String       NaN
# 7    Sage Bionetworks              NaN  Other  String       NaN
# 12   Sage Bionetworks              NaN  Other  String       NaN
# ..                ...              ...    ...     ...       ...
# 438               NaN              NaN  Other     NaN       NaN
# 439               NaN              NaN  Other     NaN       NaN
# 440               NaN              NaN  Other     NaN       NaN
# 441               NaN              NaN  Other     NaN       NaN
# 442               NaN              NaN  Other     NaN       NaN
#
# [77 rows x 15 columns]

# %%
# Fix metadata module annotation
dm.loc[
    dm["Module"].str.contains(
        "Race|Ethnicity", regex=True, flags=re.IGNORECASE, na=False
    ),
    "Module",
] = "Metadata"

# %%
# fix Possible values are listed under the cleavage
with pd.option_context("display.max_colwidth", None):
    display(dm[dm["Attribute"].str.contains("Possible values are")])
    display(dm[dm["Valid Values"].str.contains("Possible values are", na=False)])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Attribute, Description, Valid Values, DependsOn, Properties, Required, Parent, DependsOn Component, Source, Validation Rules, Module, Type, Ontology]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Attribute, Description, Valid Values, DependsOn, Properties, Required, Parent, DependsOn Component, Source, Validation Rules, Module, Type, Ontology]
# Index: []

# %%
# fixing more values

old_values = {
    "msInstrumentModel": "Possible values are listed under the instrument model term.OtherMsInstrumentModel,Unknown,Not collected,Not applicable,Not Specified",
    "modificationParameters": "Possible values are listed under modification parameters,OtherModificationParameters,Unknown,Not collected,Not applicable,Not Specified",
    "cleavageAgents": "Possible values are listed under the cleavage agent nameOtherCleavageAgents,Unknown,Not collected,Not applicable,Not Specified	",
}


# fixing values
dm.loc[dm["Attribute"] == "msInstrumentModel", "Valid Values"] = ""
dm.loc[dm["Attribute"] == "msInstrumentModel", "Validation Rules"] = "str"

dm.loc[dm["Attribute"] == "modificationParameters", "Valid Values"] = ""
dm.loc[dm["Attribute"] == "modificationParameters", "Validation Rules"] = "str"

dm.loc[dm["Attribute"] == "cleavageAgents", "Valid Values"] = ""
dm.loc[dm["Attribute"] == "cleavageAgents", "Validation Rules"] = "str"
dm.loc[dm["Attribute"] == "cleavageAgents", "Parent"] = ""

# %%
dm = dm.drop(dm[dm["Attribute"].str.contains("Possible values are")].index).reset_index(
    drop=True
)

# %%
# fix measurement units and change to just units
dm.loc[dm["Module"] == "Measurement Unit", "Module"] = "Unit"
dm.loc[dm["Module"] == "Unit", "Type"] = "NUMERIC"

# %%
# add study name attribute
dm.loc[dm["Attribute"].str.contains("study"),]
# Out:
#      Unnamed: 0.1  Unnamed: 0   Attribute
# 158           158         158   studyCode  \
# 596           596         596  study pool
# 648           648         648   studyName
#
#                                            Description
# 158  Unique identifier for the study, assigned by t...  \
# 596                                                NaN
# 648                   Name of studies found in project
#
#                                        Valid Values DependsOn  Properties
# 158                                  LC,LG,ILO,LLFS       NaN         NaN  \
# 596                                             NaN       NaN         NaN
# 648  MRGWAS,ELPSCRNA,Aging-PheWAS,Organoid scRNAseq       NaN         NaN
#
#     Required        Parent  DependsOn Component            Source
# 158     True  DataProperty                  NaN  Sage Bionetworks  \
# 596    False    ValidValue                  NaN               NaN
# 648      NaN   validValues                  NaN               NaN
#
#     Validation Rules       Module Type  Ontology
# 158              NaN     Metadata  NaN       NaN
# 596              NaN  Unspecified  NaN       NaN
# 648              NaN  Unspecified  NaN       NaN

# %%
dm.loc[dm["Attribute"].str.contains("study"),]
# Out:
#      Unnamed: 0.1  Unnamed: 0   Attribute
# 158           158         158   studyCode  \
# 596           596         596  study pool
# 648           648         648   studyName
#
#                                            Description
# 158  Unique identifier for the study, assigned by t...  \
# 596                                                NaN
# 648                   Name of studies found in project
#
#                                        Valid Values DependsOn  Properties
# 158                                  LC,LG,ILO,LLFS       NaN         NaN  \
# 596                                             NaN       NaN         NaN
# 648  MRGWAS,ELPSCRNA,Aging-PheWAS,Organoid scRNAseq       NaN         NaN
#
#     Required        Parent  DependsOn Component            Source
# 158     True  DataProperty                  NaN  Sage Bionetworks  \
# 596    False    ValidValue                  NaN               NaN
# 648      NaN   validValues                  NaN               NaN
#
#     Validation Rules       Module Type  Ontology
# 158              NaN     Metadata  NaN       NaN
# 596              NaN  Unspecified  NaN       NaN
# 648              NaN  Unspecified  NaN       NaN

# %%
# Later get from synapse
new_attribute = {
    "Attribute": ["studyName"],
    "Description": ["Name of studies found in project"],
    "Valid Values": ["MRGWAS,ELPSCRNA,Aging-PheWAS,Organoid scRNAseq"],
    "DependsOn": [np.nan],
    "Properties": [np.nan],
    "Required": [np.nan],
    "Parent": ["validValues"],
    "DependsOn Component": [np.nan],
    "Source": [np.nan],
    "Validation Rules": [np.nan],
    "Module": [np.nan],
    "Type": [np.nan],
    "Ontology": [np.nan],
}

dm = pd.concat([dm, pd.DataFrame.from_dict(new_attribute)])

# %%
recode_parent = {
    "dataProperty": "DataProperty",
    "specification": "Specification",
    "validValue": "ValidValue",
    "template": "Template",
}

dm["Parent"] = dm["Parent"].replace(recode_parent)

# %% [markdown]
# 'Metadata', 'Unspecified', 'Other', 'Omics', 'Assay Metadata',
# 'Instrument', 'Unit', 'Assay', 'Sample Type', 'Model Organism',
# 'Ontology', 'Project', 'Organ', 'Boolean', 'Tissue', 'Template',
# 'BaseAnnotation',

# %%
dm.loc[
    dm["Module"].isin(["Organ", "Tissue", "Sample Type"]), "Module"
] = "Sample Metadata"

# %%
np.sort(dm["Module"].dropna().unique())
# Out:
# array(['Assay', 'Assay Metadata', 'BaseAnnotation', 'Instrument',
#        'Metadata', 'Model Organism', 'Omics', 'Ontology', 'Other',
#        'Project', 'Sample Metadata', 'Template', 'Unit', 'Unspecified',
#        'Valid Value'], dtype=object)

# %%
dm.loc[
    dm["Module"].isin(["Omics"]), "Module"
] = "Assay"

# %%
dm.loc[
    dm["Module"].isin(["Assay", 'Assay Metadata']),]
# Out:
#      Unnamed: 0.1  Unnamed: 0                                    Attribute
# 52           52.0        52.0                                 reagentID(s)  \
# 53           53.0        53.0                                  reagentName
# 54           54.0        54.0                          reagentManufacturer
# 55           55.0        55.0                         reagentCatalogNumber
# 56           56.0        56.0                             reagentLotNumber
# 57           57.0        57.0                               reagentWeblink
# 58           58.0        58.0                               reagentContact
# 245         245.0       245.0   Affymetrix Genome-Wide Human SNP 6.0 Array
# 246         246.0       246.0           Affymetrix Human Gene 1.0 ST Array
# 247         247.0       247.0  Affymetrix Human Genome U133 Plus 2.0 Array
# 248         248.0       248.0                            Affymetrix U133AB
#
#                                            Description Valid Values DependsOn
# 52   One or more identifiers, separated by a semico...          NaN       NaN  \
# 53   The reagent name is an alternative to the Reag...          NaN       NaN
# 54   The manufacturer is the source of a reagent an...          NaN       NaN
# 55   If the assay reagent is a commercial product, ...          NaN       NaN
# 56   The lot number is often provided by a reagent ...          NaN       NaN
# 57   An internet address that may provide details o...          NaN       NaN
# 58   The contact information is particularly helpfu...          NaN       NaN
# 245                                                NaN          NaN       NaN
# 246                                                NaN          NaN       NaN
# 247                                                NaN          NaN       NaN
# 248                                                NaN          NaN       NaN
#
#      Properties Required        Parent  DependsOn Component
# 52          NaN    False  DataProperty                  NaN  \
# 53          NaN    False  DataProperty                  NaN
# 54          NaN    False  DataProperty                  NaN
# 55          NaN    False  DataProperty                  NaN
# 56          NaN    False  DataProperty                  NaN
# 57          NaN    False  DataProperty                  NaN
# 58          NaN    False  DataProperty                  NaN
# 245         NaN    False    ValidValue                  NaN
# 246         NaN    False    ValidValue                  NaN
# 247         NaN    False    ValidValue                  NaN
# 248         NaN    False    ValidValue                  NaN
#
#                        Source Validation Rules          Module Type  Ontology
# 52   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 53   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 54   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 55   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 56   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 57   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 58   Sage Bionetworks,ImmPort              NaN  Assay Metadata  NaN       NaN
# 245                       NaN              NaN           Assay  NaN       NaN
# 246                       NaN              NaN           Assay  NaN       NaN
# 247                       NaN              NaN           Assay  NaN       NaN
# 248                       NaN              NaN           Assay  NaN       NaN

# %%
# write out data model
dm.drop_duplicates(subset=["Attribute"], inplace=True)

dm.reset_index(drop=True, inplace=True)

dm.to_csv("../EL.data.model.csv", index=False)
