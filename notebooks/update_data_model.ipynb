# %%
import os
import pandas as pd
import numpy as np
import re

# %%
import datetime

today = datetime.date.today()
today_str = today.strftime("%Y-%m-%d")

# %%
dm = pd.read_csv("../EL.data.model.csv")

# %%
# write out old data model before changes
dm.to_csv(f"../backups/EL.data.model.{today_str}.csv")

# %%
dm["Module"].unique()
# Out:
# array(['Metadata', 'Unspecified', 'Other', 'Omics', 'Assay Metadata',
#        'Instrument', 'Unit', 'Assay', 'Sample Type', 'Model Organism',
#        'Ontology', 'Study', 'Organ', 'Boolean', 'Tissue', 'Template',
#        'BaseAnnotation'], dtype=object)

# %%
# Pull grant information

# %%
# Fix Other values
dm.loc[
    dm["Attribute"].str.contains(
        "^other|^specify", regex=True, flags=re.IGNORECASE),
    "Module",
] = "Other"

# %%
# Fix "specify" values
dm.loc[
    dm["Attribute"].str.contains(
        "^specify", regex=True, flags=re.IGNORECASE), "Parent"
] = "specification"

# %%
dm.loc[
    dm["Attribute"].str.contains(
        "^other|^specify", regex=True, flags=re.IGNORECASE),
]
# Out:
#                            Attribute
# 2                  specifySampleType  \
# 3        specifyMeasurementTechnique
# 5             specifyPlatformVersion
# 7            specifyPlatformLocation
# 12           specifyDNABatchSizeUnit
# ..                               ...
# 438        OtherConversionRatioUnits
# 439  OtherExperiementalBatchSizeUnit
# 440            OtherLensVoltagesUnit
# 441          OtherVacuumPressureUnit
# 442      OtherYesHasIonizationSource
#
#                                      Description Valid Values DependsOn
# 2    Value is determined by the data contributor          NaN       NaN  \
# 3    Value is determined by the data contributor          NaN       NaN
# 5    Value is determined by the data contributor          NaN       NaN
# 7    Value is determined by the data contributor          NaN       NaN
# 12   Value is determined by the data contributor          NaN       NaN
# ..                                           ...          ...       ...
# 438                                          NaN          NaN       NaN
# 439                                          NaN          NaN       NaN
# 440                                          NaN          NaN       NaN
# 441                                          NaN          NaN       NaN
# 442                                          NaN          NaN       NaN
#
#      Properties Required         Parent  DependsOn Component
# 2           NaN    False  specification                  NaN  \
# 3           NaN    False  specification                  NaN
# 5           NaN    False  specification                  NaN
# 7           NaN    False  specification                  NaN
# 12          NaN    False  specification                  NaN
# ..          ...      ...            ...                  ...
# 438         NaN    False     validValue                  NaN
# 439         NaN    False     validValue                  NaN
# 440         NaN    False     validValue                  NaN
# 441         NaN    False     validValue                  NaN
# 442         NaN    False     validValue                  NaN
#
#                Source Validation Rules Module    Type  Ontology
# 2    Sage Bionetworks              NaN  Other  String       NaN
# 3    Sage Bionetworks              NaN  Other  String       NaN
# 5    Sage Bionetworks              NaN  Other  String       NaN
# 7    Sage Bionetworks              NaN  Other  String       NaN
# 12   Sage Bionetworks              NaN  Other  String       NaN
# ..                ...              ...    ...     ...       ...
# 438               NaN              NaN  Other     NaN       NaN
# 439               NaN              NaN  Other     NaN       NaN
# 440               NaN              NaN  Other     NaN       NaN
# 441               NaN              NaN  Other     NaN       NaN
# 442               NaN              NaN  Other     NaN       NaN
#
# [77 rows x 13 columns]

# %%
# Fix metadata module annotation
dm.loc[
    dm["Module"].str.contains(
        "Race|Ethnicity", regex=True, flags=re.IGNORECASE),
    "Module",
] = "Metadata"

# %%
# for any attributes that do not currently have a module name. In an attempt to remove the bracket tab in the webpage
dm.loc[dm["Module"].isna(), "Module"] = "Unspecified"

# %%
# fix Possible values are listed under the cleavage
with pd.option_context("display.max_colwidth", None):
    display(dm[dm["Attribute"].str.contains("Possible values are")])
    display(dm[dm["Valid Values"].str.contains(
        "Possible values are", na=False)])
# Out:
#                                                                              Attribute
# 462                           Possible values are listed under modification parameters  \
# 463        Possible values are listed under the cleavage agent nameOtherCleavageAgents
# 464  Possible values are listed under the instrument model term.OtherMsInstrumentModel
#
#     Description Valid Values DependsOn  Properties Required      Parent
# 462         NaN          NaN       NaN         NaN    False  validValue  \
# 463         NaN          NaN       NaN         NaN    False  validValue
# 464         NaN          NaN       NaN         NaN    False  validValue
#
#      DependsOn Component Source Validation Rules       Module Type  Ontology
# 462                  NaN    NaN              NaN  Unspecified  NaN       NaN
# 463                  NaN    NaN              NaN  Unspecified  NaN       NaN
# 464                  NaN    NaN              NaN  Unspecified  NaN       NaN
#                   Attribute
# 77        msInstrumentModel  \
# 131  modificationParameters
# 133          cleavageAgents
#
#                                                                                             Description
# 77                                                             The model of the mass spectrometer  used  \
# 131  Modification parameters for the search engine run. [ PSI: PI http://www.w3.org/2002/07/owl#Axiom ]
# 133                                                                          Name(s) of the enzyme used
#
#                                                                                                                                 Valid Values
# 77      Possible values are listed under the instrument model term.OtherMsInstrumentModel,Unknown,Not collected,Not applicable,Not Specified  \
# 131  Possible values are listed under modification parameters,OtherModificationParameters,Unknown,Not collected,Not applicable,Not Specified
# 133           Possible values are listed under the cleavage agent nameOtherCleavageAgents,Unknown,Not collected,Not applicable,Not Specified
#
#     DependsOn  Properties Required        Parent  DependsOn Component
# 77        NaN         NaN     True  dataProperty                  NaN  \
# 131       NaN         NaN     True  dataProperty                  NaN
# 133       NaN         NaN     True  dataProperty                  NaN
#
#                                                                                                    Source
# 77                             Sage Bionetworks,Proposed minimum metadata relative to mass spectrometry    \
# 131  https://www.ebi.ac.uk/ols/ontologies/ms/termsiri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMS_1001055
# 133                                                                            Proteomics Sample Metadata
#
#     Validation Rules       Module Type  Ontology
# 77               NaN  Unspecified  NaN       NaN
# 131              NaN  Unspecified  NaN       NaN
# 133              NaN  Unspecified  NaN       NaN

# %%
# fixing more values

old_values = {
    "msInstrumentModel": "Possible values are listed under the instrument model term.OtherMsInstrumentModel,Unknown,Not collected,Not applicable,Not Specified",
    "modificationParameters": "Possible values are listed under modification parameters,OtherModificationParameters,Unknown,Not collected,Not applicable,Not Specified",
    "cleavageAgents": "Possible values are listed under the cleavage agent nameOtherCleavageAgents,Unknown,Not collected,Not applicable,Not Specified	"
}


# fixing values
dm.loc[dm['Attribute'] == "msInstrumentModel", 'Valid Values'] = ""
dm.loc[dm['Attribute'] == "msInstrumentModel", 'Validation Rules'] = "str"

dm.loc[dm['Attribute'] == "modificationParameters", 'Valid Values'] = ""
dm.loc[dm['Attribute'] == "modificationParameters", 'Validation Rules'] = "str"

dm.loc[dm['Attribute'] == "cleavageAgents", 'Valid Values'] = ""
dm.loc[dm['Attribute'] == "cleavageAgents", 'Validation Rules'] = "str"
dm.loc[dm['Attribute'] == "cleavageAgents", 'Parent'] = ""

# %%
dm = dm.drop(dm[dm["Attribute"].str.contains("Possible values are")].index).reset_index(drop = True)

# %%
# fix measurement units and change to just units
dm.loc[dm['Module'] == "Measurement Unit", 'Module'] = 'Unit'

# %%
# write out data model
dm.to_csv("../EL.data.model.csv", index=False)
